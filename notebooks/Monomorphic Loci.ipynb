# %% [markdown]
# ## Monomorphic Loci in Data Set
#
#
# When I run separate Sliding Window Analyses on my western and eastern populations, I end up with far fewer loci because Genepop is unable to calculate either pairwise or global Fst for some markers.
#
# How many monomorphic loci do I have when I split up the populations?
#
#
#
#
# #### 3/29/2018
#
#
# To calculate, I used the GenepopEdit package. Code can be found in [this R script](https://github.com/mfisher5/PCod-Compare-repo/blob/master/analyses/EastWestComparisons/Monomorphic_Loci_ByPop.R)
#
#
#
#
# #### Eastern Population
# AD06
#  764
#
# HS04
#   937
#
# JDF12
#  1471
#
# KOD03
#  894
#
# PWS12
# 1313
#
# SS1213
#  1044
#
# UP03
# 1074
#
# WC05
#   860
#
# ALL
# 198
#
#
#
# #### Western population
# BOR07
#   1505
#
# GE2015
#  1578
#
# GEO020414
# 1011
#
# JB021108
#   817
#
# JB121807
# 757
#
# JUK07
#   547
#
# NA021015
# 1955
#
# PO2015
# 1548
#
# YS121315
# 1131
#
# ALL
# 62
