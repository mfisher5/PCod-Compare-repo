# %% [markdown]
# ## Raw Reads per Demultiplexed Fastq File
#
# This calculation is for supplementary figures in Chapter Two.

# %%
pwd
# Out:
# u'/mnt/hgfs/PCod-Compare-repo/notebooks/batch8_pipeline'

# %%
cd ../../scripts
# Out:
# /mnt/hgfs/PCod-Compare-repo/scripts

# %%
# !python countreads_fastq.py -h
# Out:
# usage: countreads_fastq.py [-h] [-s SAMPLES] [-d DIRECTORY] [-os OUTPUTSHELL]
#                            [-of OUTPUT]
#
# count number of consensus seqs in .tags files
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -s SAMPLES, --samples SAMPLES
#                         file with list of samples (if paired end, should
#                         include .1 at end)
#   -d DIRECTORY, --directory DIRECTORY
#                         local path with directory with fastq files
#   -os OUTPUTSHELL, --outputshell OUTPUTSHELL
#                         bash shell script file name. must have file extension
#                         .sh
#   -of OUTPUT, --output OUTPUT
#                         text file name to store read depths, with local path.
#                         Do not include file extension

# %% [markdown]
# I'm being a bit lazy here because my alaska and korean samples are in different directories, but I'm just going to let the shell script throw errors for one half of the samples, rather than editing the script to allow for different directories in some samples.

# %%
# !python countreads_fastq.py \
-s PopMap_combo_b4.txt \
-d ../KORsamplesT92 \
-os countreads_fastq_KOR92.sh \
-of fastq_readcounts_KORt92.txt
# Out:
# Bash shell script created
# Calling shell script...
# PO010715_02_92bp
# PO010715_02_rep_92bp
# PO010715_04_92bp
# PO010715_06.1_92bp
# PO010715_08.1_92bp
# PO010715_10.1_92bp
# PO010715_11.1_92bp
# PO010715_12_92bp
# PO010715_17.1_92bp
# PO010715_19.1_92bp
# PO010715_26_92bp
# PO010715_27.1_92bp
# PO010715_28.1_92bp
# PO010715_29.1_92bp
# PO020515_01_92bp
# PO020515_03.1_92bp
# PO020515_05.1_92bp
# PO020515_06_92bp
# PO020515_08.1_92bp
# PO020515_09.1_92bp
# PO020515_10.1_92bp
# PO020515_14.1_92bp
# PO020515_15.1_92bp
# PO020515_16.1_92bp
# PO020515_17.1_92bp
# PO031715_03_92bp
# PO031715_04_92bp
# PO031715_13.1_92bp
# PO031715_20.1_92bp
# PO031715_23_92bp
# PO031715_24_92bp
# PO010715_26_2_92bp
# PO010715_07_92bp
# PO010715_07_rep_92bp
# GE011215_01.1_92bp
# GE011215_07.1_92bp
# GE011215_08.1_92bp
# GE011215_09.1_92bp
# GE011215_10.1_92bp
# GE011215_14.1_92bp
# GE011215_15.1_92bp
# GE011215_16.1_92bp
# GE011215_18_92bp
# GE011215_19_92bp
# GE011215_20.1_92bp
# GE011215_21.1_92bp
# ...

# %%
# !python countreads_fastq.py \
-s PopMap_combo_b4.txt \
-d ../AKsamplesT92 \
-os countreads_fastq_AK92.sh \
-of fastq_readcounts_AKt92.txt
# Out:
# Bash shell script created
# Calling shell script...
# PO010715_02_92bp
# cat: PO010715_02_92bp.fq: No such file or directory
# PO010715_02_rep_92bp
# cat: PO010715_02_rep_92bp.fq: No such file or directory
# PO010715_04_92bp
# cat: PO010715_04_92bp.fq: No such file or directory
# PO010715_06.1_92bp
# cat: PO010715_06.1_92bp.fq: No such file or directory
# PO010715_08.1_92bp
# cat: PO010715_08.1_92bp.fq: No such file or directory
# PO010715_10.1_92bp
# cat: PO010715_10.1_92bp.fq: No such file or directory
# PO010715_11.1_92bp
# cat: PO010715_11.1_92bp.fq: No such file or directory
# PO010715_12_92bp
# cat: PO010715_12_92bp.fq: No such file or directory
# PO010715_17.1_92bp
# cat: PO010715_17.1_92bp.fq: No such file or directory
# PO010715_19.1_92bp
# cat: PO010715_19.1_92bp.fq: No such file or directory
# PO010715_26_92bp
# cat: PO010715_26_92bp.fq: No such file or directory
# PO010715_27.1_92bp
# cat: PO010715_27.1_92bp.fq: No such file or directory
# PO010715_28.1_92bp
# ...
